# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statistics
from scipy.stats import mode

# %% [markdown]
# # Import data set

# %%
dataset = pd.read_csv('healthcare-dataset-stroke-data.csv')

x = dataset.iloc[:, 0:-1].values
y = dataset.iloc[:, -1].values

print(x, y)
# Out:
# [[9046 'Male' 67.0 ... 228.69 36.6 'formerly smoked']
#  [51676 'Female' 61.0 ... 202.21 nan 'never smoked']
#  [31112 'Male' 80.0 ... 105.92 32.5 'never smoked']
#  ...
#  [19723 'Female' 35.0 ... 82.99 30.6 'never smoked']
#  [37544 'Male' 51.0 ... 166.29 25.6 'formerly smoked']
#  [44679 'Female' 44.0 ... 85.28 26.2 'Unknown']] [1 1 1 ... 0 0 0]

# %% [markdown]
# # Count

# %%
dataset.count(axis=0)
# Out:
# id                   5110
# gender               5110
# age                  5110
# hypertension         5110
# heart_disease        5110
# ever_married         5110
# work_type            5110
# Residence_type       5110
# avg_glucose_level    5110
# bmi                  4909
# smoking_status       5110
# stroke               5110
# dtype: int64

# %% [markdown]
# # Cardinality

# %%
cardinality = dataset.nunique()
cardinality
# Out:
# id                   5110
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3979
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %% [markdown]
# # Continuous features

# %%
#Mean

print(sum(x[:, 9]))

id = statistics.mean(x[:,0])
age = statistics.mean(x[:,2])
avg_gluc = statistics.mean(x[:,8])
BMI = statistics.mean(x[:,9])

print(id, age, avg_gluc, BMI)
# Out:
# nan
# 36517.82935420744 43.226614481409 106.1476771037182 nan

# %%
id = np.mean(x[:,0])
age = np.mean(x[:,2])
avg_gluc = np.mean(x[:,8])
BMI = np.mean(x[:,9])

print(id, age, avg_gluc, BMI)
# Out:
# 36517.82935420744 43.226614481409015 106.14767710371804 nan

# %%
#Median

id = statistics.median(x[:,0])
age = statistics.median(x[:,2])
avg_gluc = statistics.median(x[:,8])
BMI = statistics.median(x[:,9])

print(id, age, avg_gluc, BMI)
# Out:
# 36932.0 45.0 91.88499999999999 45.75

# %%
id = np.quantile(x[:,0], 0.5)
age = np.quantile(x[:,2], 0.5)
avg_gluc = np.quantile(x[:,8], 0.5)
BMI = np.quantile(x[:,9], 0.5)

print(id, age, avg_gluc, BMI)
# Out:
# 36932.0 45.0 91.88499999999999 28.05

# %%
#Standard Deviation

id = statistics.stdev(x[:,0])
age = statistics.stdev(x[:,2])
avg_gluc = statistics.stdev(x[:,8])
BMI = statistics.stdev(x[:,9])

print(id, age, avg_gluc, BMI)
# Out:
# 21161.72162482717 22.61264672311349 45.28356015058198 nan

# %%
id = np.std(x[:,0])
age = np.std(x[:,2])
avg_gluc = np.std(x[:,8])
BMI = np.std(x[:,9])

print(id, age, avg_gluc, BMI)
# Out:
# 21159.650904960657 22.61043402711301 45.27912905705897 nan

# %%
#3rd Quartile

id = np.quantile(x[:,0], 0.75)
age = np.quantile(x[:,2], 0.75)
avg_gluc = np.quantile(x[:,8], 0.75)
BMI = np.quantile(x[:,9], 0.75)

print(id, age, avg_gluc, BMI)
# Out:
# 54682.0 61.0 114.09 33.1

# %%
#1st Quartile

id = np.quantile(x[:,0], 0.25)
age = np.quantile(x[:,2], 0.25)
avg_gluc = np.quantile(x[:,8], 0.25)
BMI = np.quantile(x[:,9], 0.25)

print(id, age, avg_gluc, BMI)
# Out:
# 17741.25 25.0 77.24499999999999 23.4

# %%
id = np.min(x[:,0])
age = np.min(x[:,2])
avg_gluc = np.min(x[:,8])
BMI = np.min(x[:,9])

print(id, age, avg_gluc, BMI)
# Out:
# 67 0.08 55.12 25.6
# C:\Users\F5331811\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
id = np.max(x[:,0])
age = np.max(x[:,2])
avg_gluc = np.max(x[:,8])
BMI = np.max(x[:,9])

print(id, age, avg_gluc, BMI)
# Out:
# 72940 82.0 271.74 40.0

# %% [markdown]
# # Categorical features

# %%
gender = mode(x[:,1])
hyper = mode(x[:,3])
heart = mode(x[:,4])
married = mode(x[:,5])
work = mode(x[:,6])
residence = mode(x[:,7])
smoking = mode(x[:,10])

print(gender)
print(hyper)
print(heart)
print(married)
print(work)
print(residence)
print(smoking)
# Out:
# ModeResult(mode=array(['Female'], dtype=object), count=array([2994]))
# ModeResult(mode=array([0], dtype=object), count=array([4612]))
# ModeResult(mode=array([0], dtype=object), count=array([4834]))
# ModeResult(mode=array(['Yes'], dtype=object), count=array([3353]))
# ModeResult(mode=array(['Private'], dtype=object), count=array([2925]))
# ModeResult(mode=array(['Urban'], dtype=object), count=array([2596]))
# ModeResult(mode=array(['never smoked'], dtype=object), count=array([1892]))

# %%
print(2994/5110, 4612/5110, 4834/5110, 3353/5110, 2925/5110, 2596/5110, 1892/5110)
# Out:
# 0.5859099804305283 0.9025440313111546 0.9459882583170255 0.6561643835616439 0.5724070450097848 0.5080234833659492 0.37025440313111546

# %%
gender = dataset['gender'].value_counts()
hyper = dataset['hypertension'].value_counts()
heart = dataset['heart_disease'].value_counts()
married = dataset['ever_married'].value_counts()
work = dataset['work_type'].value_counts()
residence = dataset['Residence_type'].value_counts()
smoking = dataset['smoking_status'].value_counts()
stroke = dataset['stroke'].value_counts()

print(gender)
print(hyper)
print(heart)
print(married)
print(work)
print(residence)
print(smoking) 
print(stroke)
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64
# 0    4612
# 1     498
# Name: hypertension, dtype: int64
# 0    4834
# 1     276
# Name: heart_disease, dtype: int64
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %% [markdown]
# # Histograms

# %%
import matplotlib.pyplot as plt

plt.figure(1)

plt.hist(x[:, 0], color = 'blue')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('ID number')
plt.ylabel('Density')

plt.savefig('ID_number.png', transparent=True)
plt.show()

# %%
plt.figure(2)

plt.hist(x[:, 2], color = 'blue')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Age')
plt.ylabel('Density')

plt.savefig('Age.png', transparent=True)
plt.show()

# %%
plt.figure(3)

plt.hist(x[:, 8], color = 'blue')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Average Glucose Level')
plt.ylabel('Density')

plt.savefig('Avg_Glucose.png', transparent=True)
plt.show()

# %%
plt.figure(4)

plt.hist(x[:, 9], color = 'blue')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('BMI')
plt.ylabel('Density')

plt.savefig('BMI.png', transparent=True)
plt.show()
# Out:
# C:\Users\F5331811\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\F5331811\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# # Bar plots

# %%
dataset['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
plt.figure(5)

name = ["Female", "Male", "Other"]
height = [2994, 2115, 1]

plt.bar(name, height, color = 'red')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Gender')
plt.ylabel('Density')

plt.savefig('Gender.png', transparent=True)
plt.show()

# %%
dataset['hypertension'].value_counts()
# Out:
# 0    4612
# 1     498
# Name: hypertension, dtype: int64

# %%
plt.figure(6)

name = ["No", "Yes"]
height = [4612, 498]

plt.bar(name, height, color = 'red')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Hypertension')
plt.ylabel('Density')

plt.savefig('Hypertension.png', transparent=True)
plt.show()

# %%
dataset['heart_disease'].value_counts()
# Out:
# 0    4834
# 1     276
# Name: heart_disease, dtype: int64

# %%
plt.figure(7)

name = ["No", "Yes"]
height = [4834, 276]

plt.bar(name, height, color = 'red')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Heart Disease')
plt.ylabel('Density')

plt.savefig('Heart.png', transparent=True)
plt.show()

# %%
dataset['ever_married'].value_counts()
# Out:
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64

# %%
plt.figure(8)

name = ["No", "Yes"]
height = [1757, 3353]

plt.bar(name, height, color = 'red')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Ever Married')
plt.ylabel('Density')

plt.savefig('Married.png', transparent=True)
plt.show()

# %%
dataset['work_type'].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
plt.figure(9)

name = ["Private", "Self-employed", "Children", "Govt_Job", "Never worked"]
height = [2925, 819, 687, 657, 22]

plt.bar(name, height, color = 'red')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Work Type')
plt.ylabel('Density')

plt.savefig('work_type.png', transparent=True)
plt.show()

# %%
dataset['Residence_type'].value_counts()
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %%
plt.figure(10)

name = ["Urban", "Rural"]
height = [2596, 2514]

plt.bar(name, height, color = 'red')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Residence Type')
plt.ylabel('Density')

plt.savefig('Residence.png', transparent=True)
plt.show()

# %%
dataset['smoking_status'].value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
plt.figure(11)

name = ["Never smoked", "Unknown", "Formerly smoked", "Smokes"]
height = [1892, 1544, 885, 789]

plt.bar(name, height, color = 'red')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Smoking Status')
plt.ylabel('Density')

plt.savefig('Smoking.png', transparent=True)
plt.show()

# %%
dataset['stroke'].value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
plt.figure(31)

name = ["No", "Yes"]
height = [4861, 249]

plt.bar(name, height, color = 'red')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Stroke')
plt.ylabel('Density')

plt.savefig('Stroke.png', transparent=True)
plt.show()

# %% [markdown]
# # Box plots for outliers

# %%
plt.figure(12)

plt.boxplot(x[:,2])

plt.show()

# %%
plt.figure(13)

plt.boxplot(x[:,8])

plt.savefig('Glucose_box.png', transparent=True)
plt.show()

# %%
plt.figure(14)

plt.boxplot(x[:,9])

plt.savefig('BMI_box.png', transparent=True)
plt.show()
# Out:
# C:\Users\F5331811\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1316: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\Users\F5331811\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1323: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# C:\Users\F5331811\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1331: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# C:\Users\F5331811\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1332: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],

# %% [markdown]
# # Data editing

# %%
dataset.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
missing_col = ['bmi']
 
#Technique 2: Using median to impute the missing values
for i in missing_col:
 dataset.loc[dataset.loc[:,i].isnull(),i]=dataset.loc[:,i].median()
 
x = dataset.iloc[:, 0:-1].values
y = dataset.iloc[:, -1].values

# %%
dataset = dataset.drop(columns = "id")

x = dataset.iloc[:, 0:-1].values
y = dataset.iloc[:, -1].values

dataset
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
dataset[["bmi"]] = dataset[["bmi"]].clip(0, 78)

x = dataset.iloc[:, 0:-1].values
y = dataset.iloc[:, -1].values

dataset
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %% [markdown]
# # New data analysis

# %%
dataset.count(axis=0)
# Out:
# gender               5110
# age                  5110
# hypertension         5110
# heart_disease        5110
# ever_married         5110
# work_type            5110
# Residence_type       5110
# avg_glucose_level    5110
# bmi                  5110
# smoking_status       5110
# stroke               5110
# dtype: int64

# %%
cardinality = dataset.nunique()
cardinality
# Out:
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3979
# bmi                   416
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
#Mean

age = statistics.mean(x[:,1])
avg_gluc = statistics.mean(x[:,7])
BMI = statistics.mean(x[:,8])

print(age, avg_gluc, BMI)
# Out:
# 43.226614481409 106.1476771037182 28.85545988258317

# %%
#Median

age = statistics.median(x[:,1])
avg_gluc = statistics.median(x[:,7])
BMI = statistics.median(x[:,8])

print(age, avg_gluc, BMI)
# Out:
# 45.0 91.88499999999999 28.1

# %%
#Standard Deviation

age = statistics.stdev(x[:,1])
avg_gluc = statistics.stdev(x[:,7])
BMI = statistics.stdev(x[:,8])

print(age, avg_gluc, BMI)
# Out:
# 22.61264672311349 45.28356015058198 7.650054628114035

# %%
#3rd Quartile

age = np.quantile(x[:,1], 0.75)
avg_gluc = np.quantile(x[:,7], 0.75)
BMI = np.quantile(x[:,8], 0.75)

print(age, avg_gluc, BMI)
# Out:
# 61.0 114.09 32.8

# %%
#1st Quartile

age = np.quantile(x[:,1], 0.25)
avg_gluc = np.quantile(x[:,7], 0.25)
BMI = np.quantile(x[:,8], 0.25)

print(age, avg_gluc, BMI)
# Out:
# 25.0 77.24499999999999 23.8

# %%
age = np.min(x[:,1])
avg_gluc = np.min(x[:,7])
BMI = np.min(x[:,8])

print(age, avg_gluc, BMI)
# Out:
# 0.08 55.12 10.3

# %%
age = np.max(x[:,1])
avg_gluc = np.max(x[:,7])
BMI = np.max(x[:,8])

print(age, avg_gluc, BMI)
# Out:
# 82.0 271.74 78.0

# %%
plt.figure(15)

plt.hist(x[:, 8], color = 'blue')

plt.grid(axis='y', alpha=0.75)
plt.xlabel('BMI')
plt.ylabel('Density')

plt.savefig('BMIclean.png', transparent=True)
plt.show()

# %% [markdown]
# # Scatter plot matrix

# %%
import seaborn as sns

continuous = dataset.iloc[:, [1,7,8,10]]

g = sns.pairplot(continuous, hue = "stroke")
#g.map_diag(sns.histplot, hue=None, color=".3")
g.map(sns.scatterplot)
g.add_legend()
plt.savefig('Splom2.png', transparent=True)

# %%
correlation_mat = continuous.corr()

sns.heatmap(correlation_mat, annot = True)

plt.show()
plt.savefig('correlation.png')

# %% [markdown]
# # Mulitple bar plots/ stacked bar plots

# %%
# between categorical features

# %% [markdown]
# ## Gender and hypertension

# %% [raw]
# plt.figure(31)
#
# name = ["No", "Yes"]
# height = [4861, 249]
#
# plt.bar(name, height, color = 'red')
#
# plt.grid(axis='y', alpha=0.75)
# plt.xlabel('Stroke')
# plt.ylabel('Density')
#
# plt.savefig('Stroke.png', transparent=True)
# plt.show()
#
#
# Density = [222, 276, 0, 1894, 2719, 1]
# Gender = ['M','F','O','M','F', 'O']
# Hypertension = ['Yes','Yes','Yes','No','No','No']
#
# sns.barplot(x='Hypertension',y='Density',data=dataset, hue='Gender')

# %%
#sns.set_theme(style="whitegrid")


g = sns.catplot(
    data=dataset, kind="bar",
    x=['Male','Female','Other','Male','Female', 'Other'], y=[108, 141, 0, 2007, 2853, 1], hue=['Yes','Yes','Yes','No','No','No'])


g.despine(left=True)
plt.xlabel('Gender')
plt.ylabel('Density')
plt.savefig('gen&stroke.png')

# %%
g = sns.catplot( data=dataset, kind="bar", 
                x=['1','0','1','0'], 
                y=[66, 183, 432, 4429], 
                hue=['Yes','Yes','No','No'])


g.despine(left=True)
plt.xlabel('Hypertension')
plt.ylabel('Density')
plt.savefig('hyp&stroke.png')

# %%
g = sns.catplot( data=dataset, kind="bar", 
                x=['1','0','1','0'], 
                y=[47, 202, 229, 4632], 
                hue=['Yes','Yes','No','No'])


g.despine(left=True)
plt.xlabel('Heart Disease')
plt.ylabel('Density')
plt.savefig('heart&stroke.png')

# %%
g = sns.catplot( data=dataset, kind="bar", 
                x=['Yes','No','Yes','No'], 
                y=[220, 29, 3133, 1728], 
                hue=['Yes','Yes','No','No'])


g.despine(left=True)
plt.xlabel('Ever Married')
plt.ylabel('Density')
plt.savefig('married&stroke.png')

# %%
g = sns.catplot( data=dataset, kind="bar", 
                x=['C', 'Govt','Never', 'Private','Self Emp','C', 'Govt','Never','Private','Self Emp'], 
                y=[2, 33, 0, 149, 65 ,685, 624, 22, 2776, 754], 
                hue=['Yes','Yes','Yes','Yes','Yes','No','No','No','No','No'])


g.despine(left=True)
plt.xlabel('Work Type')
plt.ylabel('Density')
plt.savefig('work&stroke.png')

# %%
g = sns.catplot( data=dataset, kind="bar", 
                x=["Urban", 'Rural', "Urban",'Rural'], 
                y=[135, 114, 2461, 2400], 
                hue=['Yes','Yes','No','No'])


g.despine(left=True)
plt.xlabel('Residence Type')
plt.ylabel('Density')
plt.savefig('res&stroke.png')

# %%
g = sns.catplot( data=dataset, kind="bar", 
                x=['FS', 'NS', 'Smokes','Unknown','FS','NS','Smokes','Unknown'], 
                y=[70, 90, 42, 47,815, 1802, 747, 1497], 
                hue=['Yes','Yes','Yes','Yes','No','No','No','No'])


plt.xlabel('Smoking Status')
plt.ylabel('Density')
plt.savefig('smoke&stroke.png')
